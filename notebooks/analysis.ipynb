# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from utils.dataloaders import load_dataset

RNG = np.random.default_rng(2023)
HOME = os.getenv("HOME")

# %%
params, series = load_dataset(
    f"{HOME}/Datasets/cell_migration/parameters.txt", 
    [
        f"{HOME}/Datasets/cell_migration/msd.txt",
        f"{HOME}/Datasets/cell_migration/dac.txt"
    ], 
    100)
# Out:
# Reading parameters from /Users/alisamar/Datasets/cell_migration/parameters.txt
# Reading 2 series from
# 	 /Users/alisamar/Datasets/cell_migration/msd.txt,
# 	/Users/alisamar/Datasets/cell_migration/dac.txt
# Parameters of Shape (100, 5)
# Series of Shape (100, 2, 79)

# %%
_ = plt.figure(figsize=(12,3))
for ts in series[:, 0]:
    plt.plot(ts, alpha=1)

# %%
_ = plt.figure(figsize=(12,3))
for ts in series[50:60, 1]:
    plt.plot(ts, alpha=1)

# %%
series[20:30, 1]
