# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from dataloaders import loadfile

RNG = np.random.default_rng(2023)
HOME = os.getenv("HOME")

# %%
params = loadfile(f"{HOME}/Datasets/cell_migration/parameters.txt")

# %%
next(params)
# Out:
# [0.9327020108217418,
#  0.42822615691526844,
#  0.011465875285306543,
#  0.02834907684261444,
#  38.15452858512533]

# %%
dac = loadfile(f"{HOME}/Datasets/cell_migration/dac.txt")
for ts in dac:
    plt.plot(ts, alpha=0.1)
# Out:
# Traceback (most recent call last):
#
#   File ~/Desktop/cell_migration/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[8], line 2
#     for ts in dac:
#
#   File ~/Desktop/cell_migration/dataloaders.py:4 in loadfile
#     yield [eval(v) for v in f.readline().split(" ")]
#
#   File ~/Desktop/cell_migration/dataloaders.py:4 in <listcomp>
#     yield [eval(v) for v in f.readline().split(" ")]
#
#   File <string>
#
#     ^
# SyntaxError: invalid syntax

# %%
msd = loadfile(f"{HOME}/Datasets/cell_migration/msd.txt")
for ts in msd:
    plt.plot(ts, alpha=0.1)
# Out:
# Traceback (most recent call last):
#
#   File ~/Desktop/cell_migration/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[7], line 2
#     for ts in msd:
#
#   File ~/Desktop/cell_migration/dataloaders.py:4 in loadfile
#     yield [eval(v) for v in f.readline().split(" ")]
#
#   File ~/Desktop/cell_migration/dataloaders.py:4 in <listcomp>
#     yield [eval(v) for v in f.readline().split(" ")]
#
#   File <string>
#
#     ^
# SyntaxError: invalid syntax
